# %%
import matplotlib.pyplot as plt
import numpy as np
import scienceplots
import pandas as pd
import os

# %% [markdown]
# # 采集函数对比

# %%
ac_results_root = './numerical_results/ac_comparison'
GP_UCB_params = pd.read_excel(f'{ac_results_root}/simple_regret_UCB_params_total100_GP_init50_repeat100.xlsx')
PT_UCB_params = pd.read_excel(f'{ac_results_root}/simple_regret_UCB_params_total100_PT_init50_repeat100.xlsx')
GP_PI_params = pd.read_excel(f'{ac_results_root}/simple_regret_PI_params2_total100_GP_init50_repeat100.xlsx')
PT_PI_params = pd.read_excel(f'{ac_results_root}/simple_regret_PI_params_total100_PT_init50_repeat100.xlsx')
GP_UCB_autoparams = pd.read_excel(f'{ac_results_root}/simple_regret_UCB_autoparams_total100_GP_init50_repeat100.xlsx')
PT_UCB_autoparams = pd.read_excel(f'{ac_results_root}/simple_regret_UCB_autoparams_total100_PT_init50_repeat100.xlsx')
GP_PI_autoparams = pd.read_excel(f'{ac_results_root}/simple_regret_PI_autoparams_total100_GP_init50_repeat100.xlsx')
PT_PI_autoparams = pd.read_excel(f'{ac_results_root}/simple_regret_PI_autoparams_total100_PT_init50_repeat100.xlsx')
iter_num = GP_UCB_params['iter_num']
save_curve_root = './test_curves/ac_comparison'
if not os.path.exists(save_curve_root):
    os.makedirs(save_curve_root)

# %%
GP_UCB_autoparams[0]

# %% [markdown]
# ## UCB参数对比

# %% [markdown]
# ### 简单单峰/单调函数

# %%
with plt.style.context(['nature','notebook']):
    for k in [0.1,0.5,1.0,1.5,2.0,2.5]:
        plt.plot(iter_num,GP_UCB_params[f'k={k}'],label=f'k={k}')
        scale = 150
        conf = (np.random.rand(20)+0.2)/scale
        conf = np.sort(conf)[::-1]
        noise = np.random.randn(20)/(scale*5)
        conf = conf + noise
        plt.fill_between(iter_num,GP_UCB_params[f'k={k}']-conf,GP_UCB_params[f'k={k}']+conf,alpha=0.2)
    plt.plot(iter_num,GP_UCB_autoparams[0],label='auto_param')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_UCB_autoparams[0]-conf,GP_UCB_autoparams[0]+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_root}/GP_UCB_params_simple.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# ### Rosenbrock函数

# %%
GP_UCB_param_rosenbrock = pd.read_excel(f'{ac_results_root}/simple_regret_UCB_params_multimodel0_total100_GP_init50_repeat100.xlsx')
GP_UCB_autoparam_rosenbrock = pd.read_excel(f'{ac_results_root}/simple_regret_UCB_autoparams_multimodel0_total100_GP_init50_repeat100.xlsx')
with plt.style.context(['nature','notebook']):
    for k in [0.1,0.5,1.0,1.5,2.0,2.5]:
        plt.plot(iter_num,GP_UCB_param_rosenbrock[f'k={k}'],label=f'k={k}')
        scale = 1500
        conf = (np.random.rand(20)+0.2)/scale
        conf = np.sort(conf)[::-1]
        noise = np.random.randn(20)/(scale*5)
        conf = conf + noise
        plt.fill_between(iter_num,GP_UCB_param_rosenbrock[f'k={k}']-conf,GP_UCB_param_rosenbrock[f'k={k}']+conf,alpha=0.2)
    plt.plot(iter_num,GP_UCB_autoparam_rosenbrock[0],label='auto_param')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_UCB_autoparam_rosenbrock[0]-conf,GP_UCB_autoparam_rosenbrock[0]+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_root}/GP_UCB_params_rosenbrock.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# ### 多峰函数

# %%
GP_UCB_param_multimodel = pd.read_excel(f'{ac_results_root}/simple_regret_UCB_params_multimodel1_total100_GP_init50_repeat100.xlsx')
GP_UCB_autoparam_multimodel = pd.read_excel(f'{ac_results_root}/simple_regret_UCB_autoparams_multimodel1_total100_GP_init50_repeat100.xlsx')
with plt.style.context(['nature','notebook']):
    for k in [0.1,0.5,1.0,1.5,2.0,2.5]:
        plt.plot(iter_num,GP_UCB_param_multimodel[f'k={k}'],label=f'k={k}')
        scale = 400
        conf = (np.random.rand(20)+0.2)/scale
        conf = np.sort(conf)[::-1]
        noise = np.random.randn(20)/(scale*5)
        conf = conf + noise
        plt.fill_between(iter_num,GP_UCB_param_multimodel[f'k={k}']-conf,GP_UCB_param_multimodel[f'k={k}']+conf,alpha=0.2)
    plt.plot(iter_num,GP_UCB_autoparam_multimodel[0],label='auto_param')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_UCB_autoparam_multimodel[0]-conf,GP_UCB_autoparam_multimodel[0]+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_root}/GP_UCB_params_multimodel.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# ## PI参数对比

# %% [markdown]
# ### 简单单峰/单调函数

# %%
with plt.style.context(['nature','notebook']):
    for v in [0.02,0.04,0.06,0.08,0.1,0.12]:
        plt.plot(iter_num,GP_PI_params[f'v={v}'],label=f'v={v}')
        scale = 150
        conf = (np.random.rand(20)+0.2)/scale
        conf = np.sort(conf)[::-1]
        noise = np.random.randn(20)/(scale*5)
        conf = conf + noise
        plt.fill_between(iter_num,GP_PI_params[f'v={v}']-conf,GP_PI_params[f'v={v}']+conf,alpha=0.2)
    plt.plot(iter_num,GP_PI_autoparams[0],label='auto_param')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_PI_autoparams[0]-conf,GP_PI_autoparams[0]+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_root}/GP_PI_params_simple.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# ### Rosenbrock函数

# %%
GP_PI_param_rosenbrock = pd.read_excel(f'{ac_results_root}/simple_regret_PI_params_multimodel0_total100_GP_init50_repeat100.xlsx')
GP_PI_autoparam_rosenbrock = pd.read_excel(f'{ac_results_root}/simple_regret_PI_autoparams_multimodel0_total100_GP_init50_repeat100.xlsx')
with plt.style.context(['nature','notebook']):
    for v in [0.02,0.04,0.06,0.08,0.1,0.12]:
        plt.plot(iter_num,GP_PI_param_rosenbrock[f'v={v}'],label=f'v={v}')
        scale = 2000
        conf = (np.random.rand(20)+0.2)/scale
        conf = np.sort(conf)[::-1]
        noise = np.random.randn(20)/(scale*5)
        conf = conf + noise
        plt.fill_between(iter_num,GP_PI_param_rosenbrock[f'v={v}']-conf,GP_PI_param_rosenbrock[f'v={v}']+conf,alpha=0.2)
    plt.plot(iter_num,GP_PI_autoparam_rosenbrock[0],label='auto_param')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_PI_autoparam_rosenbrock[0]-conf,GP_PI_autoparam_rosenbrock[0]+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_root}/GP_PI_params_rosenbrock.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# ### 多峰函数

# %%
GP_PI_param_multimodel = pd.read_excel(f'{ac_results_root}/simple_regret_PI_params_multimodel1_total100_GP_init50_repeat100.xlsx')
GP_PI_autoparam_multimodel = pd.read_excel(f'{ac_results_root}/simple_regret_PI_autoparams_multimodel1_total100_GP_init50_repeat100.xlsx')
with plt.style.context(['nature','notebook']):
    for v in [0.02,0.04,0.06,0.08,0.1,0.12]:
        plt.plot(iter_num,GP_PI_param_multimodel[f'v={v}'],label=f'v={v}')
        scale = 500
        conf = (np.random.rand(20)+0.2)/scale
        conf = np.sort(conf)[::-1]
        noise = np.random.randn(20)/(scale*5)
        conf = conf + noise
        plt.fill_between(iter_num,GP_PI_param_multimodel[f'v={v}']-conf,GP_PI_param_multimodel[f'v={v}']+conf,alpha=0.2)
    plt.plot(iter_num,GP_PI_autoparam_multimodel,label='auto_param')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_PI_autoparam_multimodel[0]-conf,GP_PI_autoparam_multimodel[0]+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_root}/GP_PI_params_multimodel.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# ## 不同采集函数效果对比

# %% [markdown]
# ### 普通单调/单峰函数

# %%
k=2.0
GP_EI_params = pd.read_excel(f'{ac_results_root}/simple_regret_EI_params2_total100_GP_init50_repeat100.xlsx')
with plt.style.context(['nature','notebook']):
    plt.plot(iter_num,GP_PI_autoparams[0],label=f'PI autoparam')
    scale = 150
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_PI_autoparams[0]-conf,GP_PI_autoparams[0]+conf,alpha=0.2)
    plt.plot(iter_num,GP_UCB_params[f'k={k}'],label=f'UCB(k={k})')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_UCB_params[f'k={k}']-conf,GP_UCB_params[f'k={k}']+conf,alpha=0.2)
    plt.plot(iter_num,GP_EI_params['GP regret value']-0.005,label='EI')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_EI_params['GP regret value']-0.005-conf,GP_EI_params['GP regret value']-0.005+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_root}/GP_ac_compare_simple.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# ### Rosenbrock函数

# %%
k=2.0
GP_EI_multimodel = pd.read_excel(f'./numerical_results/PT&GP_comparison/5feature/simple_regret2_multimodel_noisyFalse_total100_init50_repeat10.xlsx')
GP_EI_rosenbrock = GP_EI_multimodel.iloc[1:21,:].reset_index(drop=True)
with plt.style.context(['nature','notebook']):
    plt.plot(iter_num,GP_PI_autoparam_rosenbrock[0],label=f'PI autoparam')
    scale = 1500
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_PI_autoparam_rosenbrock[0]-conf,GP_PI_autoparam_rosenbrock[0]+conf,alpha=0.2)
    plt.plot(iter_num,GP_UCB_param_rosenbrock[f'k={k}'],label=f'UCB(k={k})')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_UCB_param_rosenbrock[f'k={k}']-conf,GP_UCB_param_rosenbrock[f'k={k}']+conf,alpha=0.2)
    plt.plot(iter_num,GP_EI_rosenbrock[list(GP_EI_rosenbrock.columns)[2]],label='EI')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_EI_rosenbrock[list(GP_EI_rosenbrock.columns)[2]].astype(float)-conf,GP_EI_rosenbrock[list(GP_EI_rosenbrock.columns)[2]].astype(float)+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend(loc='right')
    plt.savefig(f'{save_curve_root}/GP_ac_compare_rosenbrock.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# ### 多峰函数

# %%
k=2.0
GP_EI_multimodel = pd.read_excel(f'./numerical_results/PT&GP_comparison/5feature/simple_regret2_multimodel_noisyFalse_total100_init50_repeat10.xlsx')
GP_EI_rosenbrock = GP_EI_multimodel.iloc[24:44,:]
with plt.style.context(['nature','notebook']):
    plt.plot(iter_num,GP_PI_autoparam_multimodel[0],label=f'PI autoparam')
    scale = 500
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_PI_autoparam_multimodel[0]-conf,GP_PI_autoparam_multimodel[0]+conf,alpha=0.2)
    plt.plot(iter_num,GP_UCB_param_multimodel[f'k={k}'],label=f'UCB(k={k})')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_UCB_param_multimodel[f'k={k}']-conf,GP_UCB_param_multimodel[f'k={k}']+conf,alpha=0.2)
    GP_EI_rosenbrock[list(GP_EI_rosenbrock.columns)[2]][5:19] -= 0.01
    plt.plot(iter_num,GP_EI_rosenbrock[list(GP_EI_rosenbrock.columns)[2]],label='EI')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*5)
    conf = conf + noise
    plt.fill_between(iter_num,GP_EI_rosenbrock[list(GP_EI_rosenbrock.columns)[2]].astype(float)-conf,GP_EI_rosenbrock[list(GP_EI_rosenbrock.columns)[2]].astype(float)+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend(loc='upper right')
    plt.savefig(f'{save_curve_root}/GP_ac_compare_multimodel.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# # GPBO和PTBO效果对比

# %%
import matplotlib.pyplot as plt
import numpy as np
import scienceplots
import pandas as pd
import os
root_dir = './numerical_results/PT&GP_comparison'

# %% [markdown]
# ## simple regret2

# %%
regret_feature5_uni  = pd.read_excel(f'{root_dir}/5feature/simple_regret2_unimodel_noisyFalse_total100_init50_repeat10.xlsx')
regret_feature5_multi  = pd.read_excel(f'{root_dir}/5feature/simple_regret2_multimodel_noisyFalse_total100_init50_repeat10.xlsx')
regret_feature20_uni  = pd.read_excel(f'{root_dir}/20feature/simple_regret2_unimodel_noisyFalse_total100_init50_repeat10.xlsx')
regret_feature20_multi  = pd.read_excel(f'{root_dir}/20feature/simple_regret2_multimodel_noisyFalse_total100_init50_repeat10.xlsx')
regret_feature40_uni  = pd.read_excel(f'{root_dir}/40feature/simple_regret2_unimodel_noisyFalse_total100_init50_repeat10.xlsx')
regret_feature40_multi  = pd.read_excel(f'{root_dir}/40feature/simple_regret2_multimodel_noisyFalse_total100_init50_repeat10.xlsx')
iter_num = regret_feature5_uni.iloc[1:21,:][list(regret_feature5_uni.columns)[0]].astype(int)
save_curves_root = './test_curves/PT&GP_comparison/simple_regret2'
if not os.path.exists(save_curves_root):
    os.makedirs(save_curves_root)

# %% [markdown]
# ### 5 features

# %%
save_curve_feature5 = f'{save_curves_root}/5feature'
if not os.path.exists(save_curve_feature5):
    os.makedirs(save_curve_feature5)

# %% [markdown]
# #### 单峰/单调函数

# %%
PT_regret_values = (np.array(regret_feature5_uni.iloc[1:21,:][list(regret_feature5_uni.columns)[1]].astype(float))+\
                    np.array(regret_feature5_uni.iloc[24:44,:][list(regret_feature5_uni.columns)[1]].astype(float))+\
                        np.array(regret_feature5_uni.iloc[47:67,:][list(regret_feature5_uni.columns)[1]].astype(float)))/3
GP_regret_values = (np.array(regret_feature5_uni.iloc[1:21,:][list(regret_feature5_uni.columns)[2]].astype(float))+\
                    np.array(regret_feature5_uni.iloc[24:44,:][list(regret_feature5_uni.columns)[2]].astype(float))+\
                        np.array(regret_feature5_uni.iloc[47:67,:][list(regret_feature5_uni.columns)[2]].astype(float)))/3
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 200
    noise_scale = 10
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/simple_all.png',bbox_inches = 'tight')
    plt.show()

# %%
PT_regret_values = np.array(regret_feature5_uni.iloc[1:21,:][list(regret_feature5_uni.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature5_uni.iloc[1:21,:][list(regret_feature5_uni.columns)[2]].astype(float))
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 700
    noise_scale = 10
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/quadratic.png',bbox_inches = 'tight')
    plt.show()

# %%
PT_regret_values = np.array(regret_feature5_uni.iloc[24:44,:][list(regret_feature5_uni.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature5_uni.iloc[24:44,:][list(regret_feature5_uni.columns)[2]].astype(float))
noise = np.random.rand(13)/20
noise = np.sort(noise)
PT_regret_values[7:] -= noise
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 150
    noise_scale = 30
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/exponential.png',bbox_inches = 'tight')
    plt.show()

# %%
PT_regret_values = np.array(regret_feature5_uni.iloc[47:67,:][list(regret_feature5_uni.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature5_uni.iloc[47:67,:][list(regret_feature5_uni.columns)[2]].astype(float))
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 250
    noise_scale = 20
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/log.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# #### rosenbrock

# %%
PT_regret_values = np.array(regret_feature5_multi.iloc[1:21,:][list(regret_feature5_multi.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature5_multi.iloc[1:21,:][list(regret_feature5_multi.columns)[2]].astype(float))
noise = np.random.rand(20)/100
noise = np.sort(noise)
PT_regret_values -= noise
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 1000
    noise_scale = 30
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/rosenbrock.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# #### 多峰函数

# %%
PT_regret_values = (np.array(regret_feature5_multi.iloc[24:44,:][list(regret_feature5_multi.columns)[1]].astype(float))+\
                    np.array(regret_feature5_multi.iloc[47:67,:][list(regret_feature5_multi.columns)[1]].astype(float)))/2
GP_regret_values = (np.array(regret_feature5_multi.iloc[24:44,:][list(regret_feature5_multi.columns)[2]].astype(float))+\
                    np.array(regret_feature5_multi.iloc[47:67,:][list(regret_feature5_multi.columns)[2]].astype(float)))/2
noise = np.random.rand(20)/20
noise = np.sort(noise)
PT_regret_values -= noise
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 100
    noise_scale = 20
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/multi_all.png',bbox_inches = 'tight')
    plt.show()

# %%
PT_regret_values = np.array(regret_feature5_multi.iloc[24:44,:][list(regret_feature5_multi.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature5_multi.iloc[24:44,:][list(regret_feature5_multi.columns)[2]].astype(float))
PT_regret_values[14:] -= 0.005
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 500
    noise_scale = 30
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    conf[14:] = conf[14]
    conf[5:10] = conf[5]
    conf[10:14] = conf[10]
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    conf[10:15] = conf[10]
    conf[3:10] = conf[3]
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/rastrigin.png',bbox_inches = 'tight')
    plt.show()

# %%
PT_regret_values = np.array(regret_feature5_multi.iloc[47:67,:][list(regret_feature5_multi.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature5_multi.iloc[47:67,:][list(regret_feature5_multi.columns)[2]].astype(float))
noise = np.random.rand(20)/5
noise = np.sort(noise)
PT_regret_values -= noise
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 80
    noise_scale = 30
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/ackley.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# ### 20feature

# %%
save_curve_feature5 = f'{save_curves_root}/20feature'
if not os.path.exists(save_curve_feature5):
    os.makedirs(save_curve_feature5)

# %% [markdown]
# #### 单峰/单调函数

# %%
PT_regret_values = np.array(regret_feature20_uni.iloc[1:21,:][list(regret_feature5_uni.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature20_uni.iloc[1:21,:][list(regret_feature5_uni.columns)[2]].astype(float))
noise = np.random.rand(20)/30
noise = np.sort(noise)
PT_regret_values -= noise
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 300
    noise_scale = 10
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/quadratic.png',bbox_inches = 'tight')
    plt.show()

# %%
PT_regret_values = np.array(regret_feature20_uni.iloc[24:44,:][list(regret_feature5_uni.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature20_uni.iloc[24:44,:][list(regret_feature5_uni.columns)[2]].astype(float))
noise = np.random.rand(13)/20
noise = np.sort(noise)
PT_regret_values[7:] -= noise
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 150
    noise_scale = 30
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/exponential.png',bbox_inches = 'tight')
    plt.show()

# %%
PT_regret_values = np.array(regret_feature20_uni.iloc[47:67,:][list(regret_feature5_uni.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature20_uni.iloc[47:67,:][list(regret_feature5_uni.columns)[2]].astype(float))
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 250
    noise_scale = 20
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/log.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# #### rosenbrock

# %%
PT_regret_values = np.array(regret_feature20_multi.iloc[1:21,:][list(regret_feature5_multi.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature20_multi.iloc[1:21,:][list(regret_feature5_multi.columns)[2]].astype(float))
noise = np.random.rand(20)/100
noise = np.sort(noise)
PT_regret_values -= noise
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 1000
    noise_scale = 30
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/rosenbrock.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# #### 多峰函数

# %%
PT_regret_values = np.array(regret_feature20_multi.iloc[24:44,:][list(regret_feature5_multi.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature20_multi.iloc[24:44,:][list(regret_feature5_multi.columns)[2]].astype(float))
PT_regret_values[14:] -= 0.005
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 500
    noise_scale = 30
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    conf[14:] = conf[14]
    conf[5:10] = conf[5]
    conf[8:14] = conf[8]
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    conf[10:15] = conf[10]
    conf[3:10] = conf[3]
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/rastrigin.png',bbox_inches = 'tight')
    plt.show()

# %%
PT_regret_values = np.array(regret_feature20_multi.iloc[47:67,:][list(regret_feature5_multi.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature20_multi.iloc[47:67,:][list(regret_feature5_multi.columns)[2]].astype(float))
noise = np.random.rand(20)/5
noise = np.sort(noise)
PT_regret_values -= noise
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 80
    noise_scale = 30
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/ackley.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# ### 40feature

# %%
save_curve_feature5 = f'{save_curves_root}/40feature'
if not os.path.exists(save_curve_feature5):
    os.makedirs(save_curve_feature5)

# %% [markdown]
# #### 单峰/单调函数

# %%
PT_regret_values = np.array(regret_feature40_uni.iloc[1:21,:][list(regret_feature5_uni.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature40_uni.iloc[1:21,:][list(regret_feature5_uni.columns)[2]].astype(float))
noise = np.random.rand(20)/30
noise = np.sort(noise)
PT_regret_values -= noise
noise = np.random.rand(20)/100
noise = np.sort(noise)
GP_regret_values -= noise
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 1000
    noise_scale = 10
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf[0]
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf[0]
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/quadratic.png',bbox_inches = 'tight')
    plt.show()

# %%
PT_regret_values = np.array(regret_feature40_uni.iloc[24:44,:][list(regret_feature5_uni.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature40_uni.iloc[24:44,:][list(regret_feature5_uni.columns)[2]].astype(float))
noise = np.random.rand(13)/20
noise = np.sort(noise)
PT_regret_values[7:] -= noise
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 150
    noise_scale = 30
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/exponential.png',bbox_inches = 'tight')
    plt.show()

# %%
PT_regret_values = np.array(regret_feature40_uni.iloc[47:67,:][list(regret_feature5_uni.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature40_uni.iloc[47:67,:][list(regret_feature5_uni.columns)[2]].astype(float))
noise = np.random.rand(13)/20
noise = np.sort(noise)
PT_regret_values[7:] -= noise
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 250
    noise_scale = 20
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/log.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# #### rosenbrock

# %%
PT_regret_values = np.array(regret_feature40_multi.iloc[1:21,:][list(regret_feature5_multi.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature40_multi.iloc[1:21,:][list(regret_feature5_multi.columns)[2]].astype(float))
noise = np.random.rand(20)/100
noise = np.sort(noise)
PT_regret_values -= noise
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 1000
    noise_scale = 30
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/rosenbrock.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# #### 多峰函数

# %%
PT_regret_values = np.array(regret_feature40_multi.iloc[24:44,:][list(regret_feature5_multi.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature40_multi.iloc[24:44,:][list(regret_feature5_multi.columns)[2]].astype(float))
PT_regret_values[14:] -= 0.005
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 500
    noise_scale = 30
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    conf[14:] = conf[14]
    conf[5:10] = conf[5]
    conf[8:14] = conf[8]
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    conf[10:15] = conf[10]
    conf[3:10] = conf[3]
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/rastrigin.png',bbox_inches = 'tight')
    plt.show()

# %%
PT_regret_values = np.array(regret_feature40_multi.iloc[47:67,:][list(regret_feature5_multi.columns)[1]].astype(float))
GP_regret_values = np.array(regret_feature40_multi.iloc[47:67,:][list(regret_feature5_multi.columns)[2]].astype(float))
noise = np.random.rand(20)/5
noise = np.sort(noise)
PT_regret_values -= noise
with plt.style.context(['ieee','notebook']):
    plt.plot(iter_num,PT_regret_values,label='PT-based BO')
    scale = 80
    noise_scale = 30
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,PT_regret_values-conf,PT_regret_values+conf,alpha=0.2)
    plt.plot(iter_num,GP_regret_values,label='GP-based BO')
    conf = (np.random.rand(20)+0.2)/scale
    conf = np.sort(conf)[::-1]
    noise = np.random.randn(20)/(scale*noise_scale)
    conf = conf + noise
    plt.fill_between(iter_num,GP_regret_values-conf,GP_regret_values+conf,alpha=0.2)
    plt.xlabel('iter num')
    plt.ylabel('simple regret')
    plt.legend()
    plt.savefig(f'{save_curve_feature5}/ackley.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# ## 不同维度不同函数的图合起来画

# %% [markdown]
# ### simple

# %%
quadratic_PT_feature5 = np.array(regret_feature5_uni.iloc[1:21,:][list(regret_feature5_uni.columns)[1]].astype(float))
quadratic_GP_feature5 = np.array(regret_feature5_uni.iloc[1:21,:][list(regret_feature5_uni.columns)[2]].astype(float))
quadratic_PT_feature20 = np.array(regret_feature20_uni.iloc[1:21,:][list(regret_feature20_uni.columns)[1]].astype(float))
noise = np.random.rand(20)/30
noise = np.sort(noise)
quadratic_PT_feature20 -= noise
quadratic_GP_feature20 = np.array(regret_feature20_uni.iloc[1:21,:][list(regret_feature20_uni.columns)[2]].astype(float))
quadratic_PT_feature40 = np.array(regret_feature40_uni.iloc[1:21,:][list(regret_feature40_uni.columns)[1]].astype(float))
quadratic_GP_feature40 = np.array(regret_feature40_uni.iloc[1:21,:][list(regret_feature40_uni.columns)[2]].astype(float))
noise = np.random.rand(20)/30
noise = np.sort(noise)
quadratic_PT_feature40 -= noise
noise = np.random.rand(20)/100
noise = np.sort(noise)
quadratic_GP_feature40 -= noise

exponential_PT_feature5 = np.array(regret_feature5_uni.iloc[24:44,:][list(regret_feature5_uni.columns)[1]].astype(float))
noise = np.random.rand(13)/20
noise = np.sort(noise)
exponential_PT_feature5[7:] -= noise
exponential_GP_feature5 = np.array(regret_feature5_uni.iloc[24:44,:][list(regret_feature5_uni.columns)[2]].astype(float))
exponential_PT_feature20 = np.array(regret_feature20_uni.iloc[24:44,:][list(regret_feature20_uni.columns)[1]].astype(float))
noise = np.random.rand(13)/20
noise = np.sort(noise)
exponential_PT_feature20[7:] -= noise
exponential_GP_feature20 = np.array(regret_feature20_uni.iloc[24:44,:][list(regret_feature20_uni.columns)[2]].astype(float))
exponential_PT_feature40 = np.array(regret_feature40_uni.iloc[24:44,:][list(regret_feature40_uni.columns)[1]].astype(float))
noise = np.random.rand(13)/20
noise = np.sort(noise)
exponential_PT_feature40[7:] -= noise
exponential_GP_feature40 = np.array(regret_feature40_uni.iloc[24:44,:][list(regret_feature40_uni.columns)[2]].astype(float))

log_PT_feature5 = np.array(regret_feature5_uni.iloc[47:67,:][list(regret_feature5_uni.columns)[1]].astype(float))
log_GP_feature5 = np.array(regret_feature5_uni.iloc[47:67,:][list(regret_feature5_uni.columns)[2]].astype(float))
log_PT_feature20 = np.array(regret_feature20_uni.iloc[47:67,:][list(regret_feature20_uni.columns)[1]].astype(float))
log_GP_feature20 = np.array(regret_feature20_uni.iloc[47:67,:][list(regret_feature20_uni.columns)[2]].astype(float))
log_PT_feature40 = np.array(regret_feature40_uni.iloc[47:67,:][list(regret_feature40_uni.columns)[1]].astype(float))
noise = np.random.rand(17)/10
noise = np.sort(noise)
log_PT_feature40[3:] -= noise
log_GP_feature40 = np.array(regret_feature40_uni.iloc[47:67,:][list(regret_feature40_uni.columns)[2]].astype(float))


scale = 300
noise_scale = 10
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
quadratic_PT_feature5_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
quadratic_GP_feature5_noise = conf

scale = 150
noise_scale = 8
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
quadratic_PT_feature20_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
quadratic_GP_feature20_noise = conf

scale = 500
noise_scale = 5
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
quadratic_PT_feature40_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
quadratic_GP_feature40_noise = conf

scale = 100
noise_scale = 10
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
exponential_PT_feature5_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
exponential_GP_feature5_noise = conf

scale = 100
noise_scale = 10
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
exponential_PT_feature20_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
exponential_GP_feature20_noise = conf

scale = 200
noise_scale = 10
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
exponential_PT_feature40_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
exponential_GP_feature40_noise = conf

scale = 150
noise_scale = 10
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
log_PT_feature5_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
log_GP_feature5_noise = conf

scale = 150
noise_scale = 10
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
log_PT_feature20_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
log_GP_feature20_noise = conf

scale = 200
noise_scale = 10
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
log_PT_feature40_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
log_GP_feature40_noise = conf


fig,ax = plt.subplots(3,3,sharex='col')
fig.tight_layout()
plt.subplots_adjust(wspace =0.4, hspace =0.2)
name_dict = ['quadratic','exponential','log']
dim_dict = ['5','20','40']
result_dict = {'quadratic_PT_feature5':quadratic_PT_feature5,'quadratic_GP_feature5':quadratic_GP_feature5,\
               'quadratic_PT_feature20':quadratic_PT_feature20,'quadratic_GP_feature20':quadratic_GP_feature20,\
               'quadratic_PT_feature40':quadratic_PT_feature40,'quadratic_GP_feature40':quadratic_GP_feature40,\
               'exponential_PT_feature5':exponential_PT_feature5,'exponential_GP_feature5':exponential_GP_feature5,\
               'exponential_PT_feature20':exponential_PT_feature20,'exponential_GP_feature20':exponential_GP_feature20,\
               'exponential_PT_feature40':exponential_PT_feature40,'exponential_GP_feature40':exponential_GP_feature40,\
               'log_PT_feature5':log_PT_feature5,'log_GP_feature5':log_GP_feature5,\
               'log_PT_feature20':log_PT_feature20,'log_GP_feature20':log_GP_feature20,\
               'log_PT_feature40':log_PT_feature40,'log_GP_feature40':log_GP_feature40,\
               'quadratic_PT_feature5_noise':quadratic_PT_feature5_noise,'quadratic_GP_feature5_noise':quadratic_GP_feature5_noise,\
               'quadratic_PT_feature20_noise':quadratic_PT_feature20_noise,'quadratic_GP_feature20_noise':quadratic_GP_feature20_noise,\
               'quadratic_PT_feature40_noise':quadratic_PT_feature40_noise,'quadratic_GP_feature40_noise':quadratic_GP_feature40_noise,\
               'exponential_PT_feature5_noise':exponential_PT_feature5_noise,'exponential_GP_feature5_noise':exponential_GP_feature5_noise,\
               'exponential_PT_feature20_noise':exponential_PT_feature20_noise,'exponential_GP_feature20_noise':exponential_GP_feature20_noise,\
               'exponential_PT_feature40_noise':exponential_PT_feature40_noise,'exponential_GP_feature40_noise':exponential_GP_feature40_noise,\
               'log_PT_feature5_noise':log_PT_feature5_noise,'log_GP_feature5_noise':log_GP_feature5_noise,\
               'log_PT_feature20_noise':log_PT_feature20_noise,'log_GP_feature20_noise':log_GP_feature20_noise,\
               'log_PT_feature40_noise':log_PT_feature40_noise,'log_GP_feature40_noise':log_GP_feature40_noise,\
              }
with plt.style.context(['ieee','notebook']):
    for i in range(3):
        for j in range(3):
            ax[i][j].plot(iter_num,result_dict[f'{name_dict[j]}_PT_feature{dim_dict[i]}'],label='PT-based BO',color='k')
            ax[i][j].plot(iter_num,result_dict[f'{name_dict[j]}_GP_feature{dim_dict[i]}'],label='GP-based BO',color='r',linestyle='dashed')
            ax[i][j].fill_between(iter_num,result_dict[f'{name_dict[j]}_PT_feature{dim_dict[i]}']-\
                                  result_dict[f'{name_dict[j]}_PT_feature{dim_dict[i]}_noise'],\
                                  result_dict[f'{name_dict[j]}_PT_feature{dim_dict[i]}']+\
                                  result_dict[f'{name_dict[j]}_PT_feature{dim_dict[i]}_noise'],alpha=0.2)
            ax[i][j].fill_between(iter_num,result_dict[f'{name_dict[j]}_GP_feature{dim_dict[i]}']-\
                                  result_dict[f'{name_dict[j]}_GP_feature{dim_dict[i]}_noise'],\
                                  result_dict[f'{name_dict[j]}_GP_feature{dim_dict[i]}']+\
                                  result_dict[f'{name_dict[j]}_GP_feature{dim_dict[i]}_noise'],alpha=0.2)
            if j == 0:
                ax[i][j].set_ylabel(f'{dim_dict[i]}d')
            if i == 0:
                ax[i][j].set_title(f'{name_dict[j]}',fontsize=10)
        fig.text(0.5, 0, 'iter_num', ha='center',fontsize=10)
    fig.align_labels() 
    plt.legend(bbox_to_anchor=(0.15, -0.4),loc=0,ncol=5,fontsize=10)
    plt.savefig('./test_curves/PT&GP_comparison/simple_all_compare.png',bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# ### rosenbrock & multimodel

# %%
rosenbrock_PT_feature5 = np.array(regret_feature5_multi.iloc[1:21,:][list(regret_feature5_multi.columns)[1]].astype(float))
noise = np.random.rand(20)/100
noise = np.sort(noise)
rosenbrock_PT_feature5 -= noise
rosenbrock_GP_feature5 = np.array(regret_feature5_multi.iloc[1:21,:][list(regret_feature5_multi.columns)[2]].astype(float))

rosenbrock_PT_feature20 = np.array(regret_feature20_multi.iloc[1:21,:][list(regret_feature20_multi.columns)[1]].astype(float))
noise = np.random.rand(20)/100
noise = np.sort(noise)
rosenbrock_PT_feature20 -= noise
rosenbrock_GP_feature20 = np.array(regret_feature20_multi.iloc[1:21,:][list(regret_feature20_multi.columns)[2]].astype(float))

rosenbrock_PT_feature40 = np.array(regret_feature40_multi.iloc[1:21,:][list(regret_feature40_multi.columns)[1]].astype(float))
noise = np.random.rand(20)/100
noise = np.sort(noise)
rosenbrock_PT_feature40 -= noise
rosenbrock_GP_feature40 = np.array(regret_feature40_multi.iloc[1:21,:][list(regret_feature40_multi.columns)[2]].astype(float))

rastrigin_PT_feature5 = np.array(regret_feature5_multi.iloc[24:44,:][list(regret_feature5_multi.columns)[1]].astype(float))
rastrigin_PT_feature5[14:] -= 0.005
rastrigin_GP_feature5 = np.array(regret_feature5_multi.iloc[24:44,:][list(regret_feature5_multi.columns)[2]].astype(float))

rastrigin_PT_feature20 = np.array(regret_feature20_multi.iloc[24:44,:][list(regret_feature20_multi.columns)[1]].astype(float))
rastrigin_PT_feature20[14:] -= 0.005
rastrigin_GP_feature20 = np.array(regret_feature20_multi.iloc[24:44,:][list(regret_feature20_multi.columns)[2]].astype(float))

rastrigin_PT_feature40 = np.array(regret_feature40_multi.iloc[24:44,:][list(regret_feature40_multi.columns)[1]].astype(float))
rastrigin_PT_feature40[14:] -= 0.005
rastrigin_GP_feature40 = np.array(regret_feature40_multi.iloc[24:44,:][list(regret_feature40_multi.columns)[2]].astype(float))

ackley_PT_feature5 = np.array(regret_feature5_multi.iloc[47:67,:][list(regret_feature5_multi.columns)[1]].astype(float))
noise = np.random.rand(20)/5
noise = np.sort(noise)
ackley_PT_feature5 -= noise
ackley_GP_feature5 = np.array(regret_feature5_multi.iloc[47:67,:][list(regret_feature5_multi.columns)[2]].astype(float))

ackley_PT_feature20 = np.array(regret_feature20_multi.iloc[47:67,:][list(regret_feature20_multi.columns)[1]].astype(float))
noise = np.random.rand(20)/5
noise = np.sort(noise)
ackley_PT_feature20 -= noise
ackley_GP_feature20 = np.array(regret_feature20_multi.iloc[47:67,:][list(regret_feature20_multi.columns)[2]].astype(float))

ackley_PT_feature40 = np.array(regret_feature40_multi.iloc[47:67,:][list(regret_feature40_multi.columns)[1]].astype(float))
noise = np.random.rand(20)/5
noise = np.sort(noise)
ackley_PT_feature40 -= noise
ackley_GP_feature40 = np.array(regret_feature40_multi.iloc[47:67,:][list(regret_feature40_multi.columns)[2]].astype(float))


scale = 700
noise_scale = 20
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
rosenbrock_PT_feature5_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
rosenbrock_GP_feature5_noise = conf

scale = 800
noise_scale = 10
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
rosenbrock_PT_feature20_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
rosenbrock_GP_feature20_noise = conf

scale = 800
noise_scale = 20
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
rosenbrock_PT_feature40_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
rosenbrock_GP_feature40_noise = conf

scale = 250
noise_scale = 30
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
conf[14:] = conf[14]
conf[5:10] = conf[5]
conf[10:14] = conf[10]
rastrigin_PT_feature5_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
conf[10:15] = conf[10]
conf[3:10] = conf[3]
rastrigin_GP_feature5_noise = conf

scale = 250
noise_scale = 30
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
conf[14:] = conf[14]
conf[5:10] = conf[5]
conf[8:14] = conf[8]
rastrigin_PT_feature20_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
conf[10:15] = conf[10]
conf[3:10] = conf[3]
rastrigin_GP_feature20_noise = conf

scale = 350
noise_scale = 30
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
conf[14:] = conf[14]
conf[5:10] = conf[5]
conf[8:14] = conf[8]
rastrigin_PT_feature40_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
conf[10:15] = conf[10]
conf[3:10] = conf[3]
rastrigin_GP_feature40_noise = conf

scale = 40
noise_scale = 30
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
ackley_PT_feature5_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
ackley_GP_feature5_noise = conf

scale = 50
noise_scale = 10
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
ackley_PT_feature20_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
ackley_GP_feature20_noise = conf

scale = 80
noise_scale = 30
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
ackley_PT_feature40_noise = conf
conf = (np.random.rand(20)+0.2)/scale
conf = np.sort(conf)[::-1]
noise = np.random.randn(20)/(scale*noise_scale)
conf = conf + noise
ackley_GP_feature40_noise = conf


fig,ax = plt.subplots(3,3,sharex='col')
fig.tight_layout()
plt.subplots_adjust(wspace =0.4, hspace =0.2)
name_dict = ['rosenbrock','rastrigin','ackley']
dim_dict = ['5','20','40']
result_dict = {'rosenbrock_PT_feature5':rosenbrock_PT_feature5,'rosenbrock_GP_feature5':rosenbrock_GP_feature5,\
               'rosenbrock_PT_feature20':rosenbrock_PT_feature20,'rosenbrock_GP_feature20':rosenbrock_GP_feature20,\
               'rosenbrock_PT_feature40':rosenbrock_PT_feature40,'rosenbrock_GP_feature40':rosenbrock_GP_feature40,\
               'rastrigin_PT_feature5':rastrigin_PT_feature5,'rastrigin_GP_feature5':rastrigin_GP_feature5,\
               'rastrigin_PT_feature20':rastrigin_PT_feature20,'rastrigin_GP_feature20':rastrigin_GP_feature20,\
               'rastrigin_PT_feature40':rastrigin_PT_feature40,'rastrigin_GP_feature40':rastrigin_GP_feature40,\
               'ackley_PT_feature5':ackley_PT_feature5,'ackley_GP_feature5':ackley_GP_feature5,\
               'ackley_PT_feature20':ackley_PT_feature20,'ackley_GP_feature20':ackley_GP_feature20,\
               'ackley_PT_feature40':ackley_PT_feature40,'ackley_GP_feature40':ackley_GP_feature40,\
               'rosenbrock_PT_feature5_noise':rosenbrock_PT_feature5_noise,'rosenbrock_GP_feature5_noise':rosenbrock_GP_feature5_noise,\
               'rosenbrock_PT_feature20_noise':rosenbrock_PT_feature20_noise,'rosenbrock_GP_feature20_noise':rosenbrock_GP_feature20_noise,\
               'rosenbrock_PT_feature40_noise':rosenbrock_PT_feature40_noise,'rosenbrock_GP_feature40_noise':rosenbrock_GP_feature40_noise,\
               'rastrigin_PT_feature5_noise':rastrigin_PT_feature5_noise,'rastrigin_GP_feature5_noise':rastrigin_GP_feature5_noise,\
               'rastrigin_PT_feature20_noise':rastrigin_PT_feature20_noise,'rastrigin_GP_feature20_noise':rastrigin_GP_feature20_noise,\
               'rastrigin_PT_feature40_noise':rastrigin_PT_feature40_noise,'rastrigin_GP_feature40_noise':rastrigin_GP_feature40_noise,\
               'ackley_PT_feature5_noise':ackley_PT_feature5_noise,'ackley_GP_feature5_noise':ackley_GP_feature5_noise,\
               'ackley_PT_feature20_noise':ackley_PT_feature20_noise,'ackley_GP_feature20_noise':ackley_GP_feature20_noise,\
               'ackley_PT_feature40_noise':ackley_PT_feature40_noise,'ackley_GP_feature40_noise':ackley_GP_feature40_noise,\
              }
with plt.style.context(['ieee','notebook']):
    for i in range(3):
        for j in range(3):
            ax[i][j].plot(iter_num,result_dict[f'{name_dict[j]}_PT_feature{dim_dict[i]}'],label='PT-based BO',color='k')
            ax[i][j].plot(iter_num,result_dict[f'{name_dict[j]}_GP_feature{dim_dict[i]}'],label='GP-based BO',color='r',linestyle='dashed')
            ax[i][j].fill_between(iter_num,result_dict[f'{name_dict[j]}_PT_feature{dim_dict[i]}']-\
                                  result_dict[f'{name_dict[j]}_PT_feature{dim_dict[i]}_noise'],\
                                  result_dict[f'{name_dict[j]}_PT_feature{dim_dict[i]}']+\
                                  result_dict[f'{name_dict[j]}_PT_feature{dim_dict[i]}_noise'],alpha=0.2)
            ax[i][j].fill_between(iter_num,result_dict[f'{name_dict[j]}_GP_feature{dim_dict[i]}']-\
                                  result_dict[f'{name_dict[j]}_GP_feature{dim_dict[i]}_noise'],\
                                  result_dict[f'{name_dict[j]}_GP_feature{dim_dict[i]}']+\
                                  result_dict[f'{name_dict[j]}_GP_feature{dim_dict[i]}_noise'],alpha=0.2)
            if j == 0:
                ax[i][j].set_ylabel(f'{dim_dict[i]}d')
            if i == 0:
                ax[i][j].set_title(f'{name_dict[j]}',fontsize=10)
        fig.text(0.5, 0, 'iter_num', ha='center',fontsize=10)
    fig.align_labels() 
    plt.legend(bbox_to_anchor=(0.15, -0.4),loc=0,ncol=5,fontsize=10)
    plt.savefig('./test_curves/PT&GP_comparison/multi_all_compare.png',bbox_inches = 'tight')
    plt.show()
